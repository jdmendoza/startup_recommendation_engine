# %% [markdown]
# # Startup Recommendation Engine

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Note:** Uncomment Below To Query From MongoDB

# %%
"""
#Use script to upload CSV to mongodb

from pymongo import MongoClient
client = MongoClient('localhost', 27017)
client.list_database_names()
startups = client['startups']
res = startups['sf_startups'].find()
res_list = [item for item in res]
sf_all_df = pd.DataFrame(res_list)
""";

# %%
sf_all_df = pd.read_csv("startups_sf_2004-14_data.csv")

# %%
sf_all_df.columns
# Out:
# Index(['company_permalink', 'company_name', 'company_category_list',
#        'company_market', 'company_country_code', 'company_state_code',
#        'company_region', 'company_city', 'investor_permalink',
#        'fILIPPO Murroni', 'investor_category_list', 'investor_market',
#        'investor_country_code', 'investor_state_code', 'investor_region',
#        'investor_city', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'funded_month', 'funded_quarter',
#        'funded_year', 'raised_amount_usd'],
#       dtype='object')

# %%
sf_companies = sf_all_df.fillna(0)[["company_name","company_market","company_city","company_category_list"]].drop_duplicates()

# %%
sf_companies = sf_companies.reset_index(drop=True)

# %%
import pickle 

with open('investor_rating_dict.pickle', 'rb') as handle:
    investor_rating_dict = pickle.load(handle)
    
with open('funding_dict.pickle', 'rb') as handle:
    funding_dict = pickle.load(handle)
    
with open('max_rounds_dict.pickle', 'rb') as handle:
    max_rounds_dict = pickle.load(handle)

# %%
sf_companies["total_funding"] = sf_companies["company_name"].map(funding_dict)

# %%
sf_companies["investor_rating"] = sf_companies["company_name"].map(investor_rating_dict)

# %%
sf_companies["company_max_round"] = sf_companies["company_name"].map(max_rounds_dict)

# %%
sf_companies[sf_companies["company_name"]=="Tesla Motors"]
# Out:
#     company_name company_market company_city company_category_list  \
# 17  Tesla Motors     Automotive    Palo Alto          |Automotive|
#
#     total_funding  investor_rating  company_max_round
# 17          823.0         9.852941                6.0

# %% [markdown]
# # Data Visualizations

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import boxcox

# %%
plt.hist(list(sf_companies["investor_rating"].fillna(1)),bins=20)
plt.title("Distribution of Investor Ratings");

# %%
transformed_investor_data = boxcox(list(sf_companies["investor_rating"].fillna(1)))
plt.hist(transformed_investor_data,bins=20)
plt.title("Distribution of Investor Ratings");

# %%
plt.hist(list(sf_companies["total_funding"].fillna(0.01).apply(np.log)),bins=20);
plt.title("Distribution of Funding");

# %%
plt.hist(list(sf_companies["company_max_round"].fillna(0)),bins=10);
plt.title("Distribution of Max Rounds");

# %% [markdown]
# ### Normalizing Company Rounds Data
#
# No Transformation seems to help

# %%
transformed_rounds_data = boxcox(list(sf_companies["company_max_round"].fillna(0).map(lambda x: 0.11 if x == 0 else x )))
plt.hist(transformed_rounds_data[0],bins=20)
plt.title("Distribution of Investor Ratings");

# %%
df = sf_companies.fillna(0)

# %%
df['total_funding'] = list(sf_companies["total_funding"].fillna(0.01).apply(np.log))
df['company_max_round'] = transformed_rounds_data[0]

print(df.shape)
df.head()
# Out:
# (4589, 7)
#     company_name       company_market   company_city  \
# 0   VirtualLogix             Software      Sunnyvale
# 1           Deem           E-Commerce  San Francisco
# 2  Pandora Media         Broadcasting        Oakland
# 3      PlayFirst                Games  San Francisco
# 4     Socialtext  Enterprise Software      Palo Alto
#
#                                company_category_list  total_funding  \
# 0                   |Mobile|Virtualization|Software|       3.377211
# 1  |Trading|Marketplaces|Content Syndication|Prod...       6.247860
# 2               |Broadcasting|Video Streaming|Music|       4.030695
# 3                        |iPhone|Mobile Games|Games|       3.630190
# 4  |Collaboration|Software|Networking|Web Tools|E...       3.845242
#
#    investor_rating  company_max_round
# 0        10.000000           0.443338
# 1         9.821429           0.674540
# 2         9.727273           0.611076
# 3        10.000000           0.560349
# 4         9.818182           0.611076

# %% [markdown]
# ## EDA Most Common Words

# %%
import matplotlib.pyplot as plt

keywords = df['company_category_list'].map(lambda x: str(x).lower().split("|"))
keywords = [item for sublist in keywords for item in sublist]

from collections import Counter

common_category_words = Counter(keywords).most_common(30)
common_category_words.pop(0)

common_market_words = Counter(list(df['company_market'])).most_common(30)

common_cities = Counter(list(df['company_city'])).most_common(30)

# %%
def create_plot(x, y, title, x_label, y_label):
    plt.figure(figsize=(15,8))
    plt.bar(x,y)
    plt.xticks(rotation=90);
    plt.title(title,fontsize=20)
    plt.xlabel(x_label,fontsize=20)
    plt.xticks(fontsize=15)
    plt.ylabel(y_label,fontsize=25)
    plt.yticks(fontsize=15)
    plt.show()

# %%
x = [w[0] for w in common_category_words]
y = [w[1] for w in common_category_words]

create_plot(x, y, "Most Common Words in Category List", "Count", "Category")

# %%
x = [w[0] if w[0] != 0 else 'None' for w in common_market_words]
y = [w[1] if w[1] != 0 else 'None' for w in common_market_words]

create_plot(x, y, "Most Common Words in Market", "Count", "Market")

# %%
x = [w[0] for w in common_cities]
y = [w[1] for w in common_cities]

create_plot(x, y, "Most Common Cities", "Count", "Category")

# %% [markdown]
# ## Clustering Section

# %%
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn import preprocessing


def clustify(df, k_keywords):
    
    """
    params: df = dataframe of startups
            k_keywords = number of clusters for keywords in category list
            
    description: This function cleans and vectorizes the company_category_list. It is then clustered by categories 
                 and added to the dataframe. The subsets of clusters are copied to X_prescaling for scaling
                 before the final clustering.
    
    returns: The dataframe with the clusters as a feature
    """

    X_keyword = df['company_category_list'].map(lambda x: ' '.join(str(x).lower().split("|")))
    vectorizer = TfidfVectorizer()
    X_vectorized = vectorizer.fit_transform(X_keyword)

    model = KMeans(n_clusters=k_keywords, init='k-means++', max_iter=100, n_init=1)
    keyword_clusters = model.fit_predict(X_vectorized)
    
    """   
    print("Top terms per cluster:")
    order_centroids = model.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names()
    for i in range(k_keywords):
        print("Cluster %d:" % i),
        for ind in order_centroids[i, :5]:
            print(' %s' % terms[ind]),
        print
    """
    
    keyword_cluster_dict = dict(zip(list(df['company_name']),keyword_clusters))
    df['keyword_clusters'] = df['company_name'].map(keyword_cluster_dict)
    
    #Cluster the already keyword clustered data
    final_cluster_dict = {}
    max_k_inner = 0
    
    for k_inner in range(k_keywords):
        
        df_subset = df[df["keyword_clusters"]==k_inner]
        
        if df_subset.shape[0] <= 5:
            max_k_inner +=1
            final_cluster_dict = dict(list(final_cluster_dict.items()) + list(dict(zip(list(df_subset['company_name']), [max_k_inner]*df_subset.shape[0])).items())) 
            #print (final_cluster_dict)
        
        else:
            '''
            The number of clusters within the keywords clusters is the floor of startups in a cluster divided by 5
            '''
            k_nums = int(df_subset.shape[0]/5) 
            
            X_prescaling = df_subset[['total_funding','company_max_round','investor_rating']]
            X_prescaling = X_prescaling.fillna(0)
            X_scaled  = pd.DataFrame(preprocessing.scale(X_prescaling))
            #X_scaled['company_name'] = df['company_name']
        
            num_clust = KMeans(n_clusters=k_nums)
            num_clusters = num_clust.fit_predict(X_scaled)   
            adj_num_clusters = [x + max_k_inner for x in num_clusters]
            
            max_k_inner += k_nums
            
            final_cluster_dict = dict(list(final_cluster_dict.items()) + list(dict(zip(list(df_subset['company_name']), adj_num_clusters)).items()))
    
        df['final_cluster'] = df['company_name'].map(final_cluster_dict)
    
    return df

# %%
clustify(sf_companies, 30)
# Out:
#                          company_name             company_market  \
# 0                        VirtualLogix                   Software
# 1                                Deem                 E-Commerce
# 2                       Pandora Media               Broadcasting
# 3                           PlayFirst                      Games
# 4                          Socialtext        Enterprise Software
# 5                            SideStep                     Hotels
# 6                         Soundflavor                      Music
# 7                    Executive Caddie                     iPhone
# 8                            VisualOn                   Software
# 9                  Innovative Silicon             Semiconductors
# 10                          Gracenote                      Music
# 11                    Aperto Networks                     Mobile
# 12                         Polimetrix                  Analytics
# 13                         StrongView        Enterprise Software
# 14                          Mobissimo                     Travel
# 15                              Plaxo                Curated Web
# 16                            LiveOps            Cloud Computing
# 17                       Tesla Motors                 Automotive
# 18                           Firetide                     Mobile
# 19                            Art.com                     Design
# 20                             CAPNIA                Health Care
# 21                            Blazent        Enterprise Software
# 22                              eASIC             Semiconductors
# 23                       ChemoCentryx                Health Care
# 24                      Sadra Medical                Health Care
# 25                        Nanostellar             Nanotechnology
# 26                             Danger                   Software
# 27      Alpha and Omega Semiconductor                 Technology
# 28                      Fathom Online                Advertising
# 29                             Akimbo          Personal Branding
# ...                               ...                        ...
# 4559                        Chartcube              Collaboration
# 4560  Prostate Management Diagnostics                          0
# 4561                      Spirometrix            Medical Devices
# 4562                           Ziarco              Biotechnology
# 4563                           UpLift                 Technology
# 4564                             VIDA       E-Commerce Platforms
# 4565                        SunFunder           Clean Technology
# 4566                        Arkin Net                          0
# 4567                  LAFORGE Optical          Augmented Reality
# 4568                 Exploration Labs        Sales and Marketing
# 4569                 Sliced Investing         Financial Services
# 4570        Heirloom Technology, Inc.                    Android
# 4571                            Shift                 Technology
# 4572                   Menlo Security                          0
# 4573                             Clef     User Experience Design
# 4574                          Bipsync            Stock Exchanges
# 4575                       Mainframe2             Virtualization
# 4576                         Assembly                   Software
# 4577                    BBVA Ventures                          0
# 4578            Sentient Technologies                   Software
# 4579                       PocketMath      Advertising Platforms
# 4580    Fluc - Food Lovers United Co.  Collaborative Consumption
# 4581                 Forward Networks                  Computers
# 4582                     Elance-oDesk         Virtual Workforces
# 4583                        Boomtown!         Tech Field Support
# 4584                         Mobilize      Productivity Software
# 4585                          Feastly                   Internet
# 4586                         Purse.IO                    Bitcoin
# 4587            LoudCell Technologies                   Software
# 4588                  Ascendis Pharma                          0
#
#            company_city                              company_category_list  \
# 1         San Francisco     516.905435         9.821429                8.0
# 2               Oakland      56.300000         9.727273                4.0
# 3         San Francisco      37.720000        10.000000                3.0
# 4             Palo Alto      46.770000         9.818182                4.0
# 5           Santa Clara      32.000000        10.000000                3.0
# 6         San Francisco       5.800000         7.400000                1.0
# 7         Mountain View       3.000000         6.000000                0.0
# 8              San Jose       2.700000         7.500000                2.0
# 9           Santa Clara      72.000000        10.000000                3.0
# 10           Emeryville      33.400000         9.250000                4.0
# 11             Milpitas     160.279779         9.972973                6.0
# 12            Palo Alto       3.000000        10.000000                1.0
# 13         Redwood City      38.100000        10.000000                4.0
# 14        San Francisco       1.000000        10.000000                0.0
# 15            Sunnyvale      28.300000        10.000000                4.0
# 16         Redwood City      81.000000         9.857143                3.0
# 17            Palo Alto     823.000000         9.852941                6.0
# 18             Campbell      39.790000         9.600000                5.0
# 19           Emeryville      26.240000        10.000000                3.0
# 20            Palo Alto      22.219087        10.000000                2.0
# 21            San Mateo      51.275260        10.000000                3.0
# 22          Santa Clara     139.143676         9.950000                5.0
# 23        Mountain View      80.540000         9.812500                4.0
# 24             Campbell      62.000000         9.800000                3.0
# 25         Redwood City      13.050000         9.000000                5.0
# 26            Palo Alto     118.300000        10.000000                5.0
# 27            Sunnyvale       1.750000         5.000000                0.0
# 28        San Francisco       6.000000        10.000000                1.0
# 29            San Mateo      36.150000        10.000000                4.0
# ...                 ...            ...              ...                ...
# 4559         Burlingame       4.550000        10.000000                NaN
# 4560      San Francisco            NaN              NaN                NaN
# 4561         Pleasanton       8.600000         7.000000                NaN
# 4562          Palo Alto      40.601832         9.800000                NaN
# 4563          Sunnyvale       8.199999         9.333333                NaN
# 4564      San Francisco       1.300000         8.200000                NaN
# 4565      San Francisco       2.500000         6.000000                NaN
# 4566      Mountain View            NaN              NaN                NaN
# 4567          San Mateo       1.100000         4.000000                NaN
# 4568      San Francisco       0.118000        10.000000                NaN
# 4569      San Francisco       2.000000         8.714286                NaN
# 4570      San Francisco       1.000000         8.500000                NaN
# 4571      San Francisco       0.120000         4.000000                NaN
# 4572         Menlo Park            NaN              NaN                NaN
# 4573            Oakland       3.020673         9.000000                NaN
# 4574          Palo Alto       1.500000         7.333333                NaN
# 4575         Menlo Park       2.200000        10.000000                NaN
# 4576      San Francisco       2.900000        10.000000                NaN
# 4577      San Francisco            NaN              NaN                NaN
# 4578      San Francisco     105.780450        10.000000                NaN
# 4579      San Francisco      10.000000         8.000000                NaN
# 4580         Menlo Park       2.300000         7.800000                NaN
# 4581          Los Altos      11.149993         9.333333                NaN
# 4582      Mountain View      30.000000        10.000000                NaN
# 4583  Belvedere Tiburon       3.000000        10.000000                NaN
# 4584      San Francisco       1.200000         7.666667                NaN
# 4585      San Francisco       1.250000        10.000000                NaN
# 4586      San Francisco       0.300000         4.500000                NaN
# 4587        Santa Clara       1.000000         4.000000                NaN
# 4588          Palo Alto            NaN              NaN                NaN
#
#       keyword_clusters  final_cluster
# 0                    9            501
# 1                    9            303
# 2                    0              9
# 3                   19            731
# 4                    9            506
# 5                    9            444
# 6                   28            906
# 7                    9            452
# 8                    1             60
# 9                    8            278
# 10                  28            908
# 11                   9            341
# 12                  23            814
# 13                   7            237
# 14                   9            396
# 15                   9            436
# 16                  29            933
# 17                   9            298
# 18                  15            665
# 19                   9            402
# 20                  10            530
# 21                  12            576
# 22                   8            265
# 23                  13            600
# 24                  21            775
# 25                   9            397
# 26                   1             46
# 27                   8            262
# 28                  17            707
# 29                  11            549
# ...                ...            ...
# 4559                 9            293
# 4560                 9            285
# 4561                 9            411
# 4562                 3            167
# 4563                 4            202
# 4564                 6            235
# 4565                 4            194
# 4566                 9            285
# 4567                 9            336
# 4568                 7            243
# 4569                 9            513
# 4570                16            673
# 4571                 4            201
# 4572                 9            285
# 4573                 9            355
# 4574                 9            401
# 4575                29            913
# 4576                 9            477
# 4577                 9            285
# 4578                 1             18
# 4579                17            709
# 4580                 9            431
# 4581                 9            455
# 4582                 9            358
# 4583                 9            477
# 4584                24            829
# 4585                 9            396
# 4586                 9            433
# 4587                 1             51
# 4588                 9            285
#
# [4589 rows x 10 columns]

# %% [markdown]
# ## Choose K for clusters
#
# Selecting 30 after looking at graph

# %%
range_n_clusters = list(range(2,50))
scores = []              
for n_clusters in range_n_clusters:

    X_keyword = df['company_category_list'].map(lambda x: ' '.join(str(x).lower().split("|")))
    vectorizer = TfidfVectorizer()
    X_vectorized = vectorizer.fit_transform(X_keyword)

    model = KMeans(n_clusters=n_clusters, init='k-means++', n_init=1)

    cluster_labels = model.fit_predict(X_vectorized)

    silhouette_avg = silhouette_score(X_vectorized, cluster_labels)
    scores.append(silhouette_avg)
    #print("For n_clusters =", n_clusters,
    #      "The average silhouette_score is :", silhouette_avg)

# %%
plt.scatter(list(range(2,50)),scores)
plt.xlabel("# of Clusters")
plt.ylabel("Silhouette Score")
# Out:
# Text(0,0.5,'Silhouette Score')

# %%
clustered_df = clustify(df,30)
clustered_df
# Out:
#                          company_name             company_market  \
# 0                        VirtualLogix                   Software
# 1                                Deem                 E-Commerce
# 2                       Pandora Media               Broadcasting
# 3                           PlayFirst                      Games
# 4                          Socialtext        Enterprise Software
# 5                            SideStep                     Hotels
# 6                         Soundflavor                      Music
# 7                    Executive Caddie                     iPhone
# 8                            VisualOn                   Software
# 9                  Innovative Silicon             Semiconductors
# 10                          Gracenote                      Music
# 11                    Aperto Networks                     Mobile
# 12                         Polimetrix                  Analytics
# 13                         StrongView        Enterprise Software
# 14                          Mobissimo                     Travel
# 15                              Plaxo                Curated Web
# 16                            LiveOps            Cloud Computing
# 17                       Tesla Motors                 Automotive
# 18                           Firetide                     Mobile
# 19                            Art.com                     Design
# 20                             CAPNIA                Health Care
# 21                            Blazent        Enterprise Software
# 22                              eASIC             Semiconductors
# 23                       ChemoCentryx                Health Care
# 24                      Sadra Medical                Health Care
# 25                        Nanostellar             Nanotechnology
# 26                             Danger                   Software
# 27      Alpha and Omega Semiconductor                 Technology
# 28                      Fathom Online                Advertising
# 29                             Akimbo          Personal Branding
# ...                               ...                        ...
# 4559                        Chartcube              Collaboration
# 4560  Prostate Management Diagnostics                          0
# 4561                      Spirometrix            Medical Devices
# 4562                           Ziarco              Biotechnology
# 4563                           UpLift                 Technology
# 4564                             VIDA       E-Commerce Platforms
# 4565                        SunFunder           Clean Technology
# 4566                        Arkin Net                          0
# 4567                  LAFORGE Optical          Augmented Reality
# 4568                 Exploration Labs        Sales and Marketing
# 4569                 Sliced Investing         Financial Services
# 4570        Heirloom Technology, Inc.                    Android
# 4571                            Shift                 Technology
# 4572                   Menlo Security                          0
# 4573                             Clef     User Experience Design
# 4574                          Bipsync            Stock Exchanges
# 4575                       Mainframe2             Virtualization
# 4576                         Assembly                   Software
# 4577                    BBVA Ventures                          0
# 4578            Sentient Technologies                   Software
# 4579                       PocketMath      Advertising Platforms
# 4580    Fluc - Food Lovers United Co.  Collaborative Consumption
# 4581                 Forward Networks                  Computers
# 4582                     Elance-oDesk         Virtual Workforces
# 4583                        Boomtown!         Tech Field Support
# 4584                         Mobilize      Productivity Software
# 4585                          Feastly                   Internet
# 4586                         Purse.IO                    Bitcoin
# 4587            LoudCell Technologies                   Software
# 4588                  Ascendis Pharma                          0
#
#            company_city                              company_category_list  \
# 0             Sunnyvale                   |Mobile|Virtualization|Software|
# 1         San Francisco  |Trading|Marketplaces|Content Syndication|Prod...
# 2               Oakland               |Broadcasting|Video Streaming|Music|
# 3         San Francisco                        |iPhone|Mobile Games|Games|
# 4             Palo Alto  |Collaboration|Software|Networking|Web Tools|E...
# 5           Santa Clara                          |Ticketing|Hotels|Travel|
# 6         San Francisco                                 |Ediscovery|Music|
# 7         Mountain View           |Windows Phone 7|iPhone|Sports|Software|
# 8              San Jose                                         |Software|
# 9           Santa Clara                                   |Semiconductors|
# 10           Emeryville                                      |Music|Games|
# 11             Milpitas                                  |Wireless|Mobile|
# 12            Palo Alto                                        |Analytics|
# 13         Redwood City  |SaaS|Advertising|Displays|Social Media|Email ...
# 14        San Francisco                                           |Travel|
# 15            Sunnyvale  |Trading|Synchronization|Databases|Contact Man...
# 16         Redwood City  |Crowdsourcing|Cloud Computing|Enterprise Soft...
# 17            Palo Alto                                       |Automotive|
# 18             Campbell                                           |Mobile|
# 19           Emeryville                                       |Art|Design|
# 20            Palo Alto  |Health Care|Health and Wellness|Gas|Medical|B...
# 21            San Mateo                              |Enterprise Software|
# 22          Santa Clara                                   |Semiconductors|
# 23        Mountain View                        |Health Care|Biotechnology|
# 24             Campbell                                      |Health Care|
# 25         Redwood City                                   |Nanotechnology|
# 26            Palo Alto                                         |Software|
# 27            Sunnyvale                        |Technology|Semiconductors|
# 28        San Francisco                                      |Advertising|
# 29            San Mateo               |Recruiting|Personal Branding|Games|
# ...                 ...                                                ...
# 4559         Burlingame  |Data Visualization|Collaboration|Freemium|Mob...
# 4560      San Francisco                                                  0
# 4561         Pleasanton                                  |Medical Devices|
# 4562          Palo Alto                                    |Biotechnology|
# 4563          Sunnyvale                                       |Technology|
# 4564      San Francisco                  |E-Commerce Platforms|E-Commerce|
# 4565      San Francisco                         |Clean Technology|Finance|
# 4566      Mountain View                                                  0
# 4567          San Mateo            |Augmented Reality|Hardware + Software|
# 4568      San Francisco                          |Sales and Marketing|B2B|
# 4569      San Francisco            |Finance Technology|Financial Services|
# 4570      San Francisco             |Android|Photo Sharing|App Stores|iOS|
# 4573            Oakland       3.020673         9.000000                0.0
# 4574          Palo Alto       1.500000         7.333333                0.0
# 4575         Menlo Park       2.200000        10.000000                0.0
# 4576      San Francisco       2.900000        10.000000                0.0
# 4577      San Francisco       0.000000         0.000000                0.0
# 4578      San Francisco     105.780450        10.000000                0.0
# 4579      San Francisco      10.000000         8.000000                0.0
# 4580         Menlo Park       2.300000         7.800000                0.0
# 4581          Los Altos      11.149993         9.333333                0.0
# 4582      Mountain View      30.000000        10.000000                0.0
# 4583  Belvedere Tiburon       3.000000        10.000000                0.0
# 4584      San Francisco       1.200000         7.666667                0.0
# 4585      San Francisco       1.250000        10.000000                0.0
# 4586      San Francisco       0.300000         4.500000                0.0
# 4587        Santa Clara       1.000000         4.000000                0.0
# 4588          Palo Alto       0.000000         0.000000                0.0
#
#       keyword_clusters  final_cluster
# 0                    7            391
# 1                   20            725
# 2                    5            194
# 3                   23            813
# 4                    7            388
# 5                    7            315
# 6                    7            309
# 7                    7            416
# 8                    1             48
# 9                   13            595
# 10                  23            820
# 11                   7            397
# 12                  14            621
# 13                  25            842
# 14                   7            266
# 15                   7            451
# 16                  27            869
# 17                   7            257
# 18                   4            174
# 19                   7            358
# 20                  11            546
# 21                  16            685
# 22                  13            596
# 23                   2             89
# 24                   2             97
# 25                   7            390
# 26                   1             38
# 27                  13            591
# 28                  22            784
# 29                   7            288
# ...                ...            ...
# 4559                 7            367
# 4560                 7            250
# 4561                 7            444
# 4562                 8            479
# 4563                12            573
# 4564                24            830
# 4565                12            566
# 4566                 7            250
# 4567                 7            295
# 4568                25            836
# 4569                 0              0
# 4570                28            884
# 4571                12            564
# 4572                 7            250
# 4573                 7            335
# 4574                 7            376
# 4575                27            857
# 4576                 7            367
# 4577                 7            250
# 4578                 1             76
# 4579                22            793
# 4580                 7            256
# 4581                 7            339
# 4582                 7            327
# 4583                 7            367
# 4584                 7            419
# 4585                 7            266
# 4586                 7            267
# 4587                 1             44
# 4588                 7            250
#
# [4589 rows x 10 columns]

# %%
clustered_df[clustered_df["final_cluster"]==6]
# Out:
#     company_name company_market company_city company_category_list  \
# 833     Bill.com           SaaS    Palo Alto        |SaaS|Finance|
#
#     company_city  total_funding  investor_rating  company_max_round  \
# 833    Palo Alto           72.6         9.851852                5.0
#
#      keyword_clusters  final_cluster
# 833                 0              6

# %%
def check_cluster_sizes(value_counts):
    list_ = list(zip(value_counts.keys(),value_counts.values))
    return(list_)

# %%
print("(Cluster number, Amount in cluster)")
print("-------")
print(check_cluster_sizes(clustered_df['final_cluster'].value_counts()))
# Out:
# (Cluster number, Amount in cluster)
# -------
# [(266, 83), (367, 54), (250, 49), (37, 40), (328, 39), (169, 34), (134, 34), (210, 33), (335, 33), (811, 32), (612, 32), (717, 28), (55, 26), (761, 25), (669, 25), (857, 25), (537, 25), (579, 23), (467, 23), (900, 22), (774, 22), (8, 22), (741, 21), (701, 21), (504, 21), (393, 20), (523, 20), (119, 20), (629, 20), (92, 20), (692, 20), (563, 19), (662, 19), (479, 18), (459, 18), (276, 18), (161, 18), (271, 18), (884, 18), (836, 17), (0, 17), (280, 17), (244,
), (44, 5), (788, 5), (748, 5), (766, 5), (30, 5), (768, 5), (101, 5), (899, 5), (794, 5), (71, 5), (500, 5), (315, 5), (805, 5), (17, 5), (158, 5), (391, 5), (104, 5), (246, 4), (300, 4), (740, 4), (897, 4), (553, 4), (499, 4), (432, 4), (503, 4), (476, 4), (346, 4), (208, 4), (362, 4), (525, 4), (370, 4), (496, 4), (561, 4), (186, 4), (372, 4), (378, 4), (194, 4), (198, 4), (785, 4), (91, 4), (789, 4), (395, 4), (589, 4), (713, 4), (443, 4), (47, 4), (79, 4), (895, 4), (609, 4), (87, 4), (889, 4), (386, 4), (368, 4), (742, 4), (361, 4), (77, 4), (215, 4), (148, 4), (696, 4), (88, 4), (694, 4), (878, 4), (690, 4), (566, 4), (136, 4), (867, 4), (13, 4), (221, 4), (596, 4), (600, 4), (237, 4), (859, 4), (642, 4), (638, 4), (664, 4), (607, 4), (485, 4), (155, 4), (426, 4), (192, 4), (117, 4), (184, 4), (864, 4), (843, 4), (543, 4), (660, ...

# %%
#clustered_df.to_csv('clustered_df.csv',sep=',',index=False)

# %% [markdown]
# ## Function To Filter Precomputed Data

# %%
def showTopCompanies(df, enteredCompany):
    
    """
    params: df = dataframe of startups
            enteredCompany = company of name of interest 
            
    description: Filters the dataframe to show companies within the same cluster as the comapny of interest
    
    returns: dashboard and the clustered companies
            
    """
    
    company_data = df[df["company_name"]==enteredCompany]
    cluster_group = company_data.iloc[0]['final_cluster']    
    group = df[df['final_cluster']==cluster_group]
    
    fig = dashboard(group, enteredCompany)
    plot(fig, filename='name.html', auto_open=False)
    
    return fig, group

# %% [markdown]
# ## Experimental Dashboard Functionality
#
# See README for link to deployed dashboard

# %%
from plotly import tools
import plotly.plotly as py
import plotly.graph_objs as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

def dashboard(df_plt, company_name):
    
    """
    params: df_plt = dataframe to be plotted
            company_name = startup of interest
            
    description: creates subplots to display various metrics of companies that were clustered together.
    
    returns: displays a figure with subplots and the object is returned as well. 
    """
    
    searched_df = df_plt[df_plt['company_name'] == company_name]
    similar_df = df_plt[df_plt['company_name'] != company_name]
    
    '''
    #Plotly doesn't support tables subplot, needs to be removed for subplot
    trace1 = go.Table(
        header=dict(values=[1,2],
                    #fill = dict(color='#C2D4FF'),
                    align = ['left'] * 5),
        cells=dict(values=[1,2],
                   #fill = dict(color='#F5F8FF'),
                   align = ['left'] * 5)
    )
    '''
    
    trace2 = go.Bar(
        x=[x for x in searched_df['company_name']] + [x for x in similar_df['company_name']],
        y=list(searched_df['total_funding']) + list(similar_df['total_funding']),
        #text=['Text A', 'Text B', 'Text C'],
    )
    
    trace3 = go.Bar(
        name='Test',
        x=[x for x in searched_df['company_name']] + [x for x in similar_df['company_name']],
        y=list(searched_df['company_max_round']) + list(similar_df['company_max_round']),
        #text=['Text D', 'Text E', 'Text F'],
    )
    
    trace4 = go.Bar(
        name='Test',
        x=[x for x in searched_df['company_name']] + [x for x in similar_df['company_name']],
        y=list(searched_df['investor_rating']) + list(similar_df['investor_rating']),
        #text=['Text D', 'Text E', 'Text F'],
    )
    
    fig = tools.make_subplots(rows=2, cols=3,subplot_titles=('Total Funding', 'Rounds','Investor Rating'))

    #fig.append_trace(trace1, 1, 1)
    fig.append_trace(trace2, 1, 1)
    fig.append_trace(trace3, 1, 2)
    fig.append_trace(trace4, 1, 3)


    fig['layout'].update(height=600, width=800,showlegend = False, title=f'Companies Similar To *{company_name}*')
    #py.iplot(fig, filename='simple-subplot-with-annotations')
    iplot(fig,filename='basic')
    
    return fig
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Example Dashboard

# %%
fig, group = showTopCompanies(clustered_df, 'Pure Storage')
group
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]  [ (1,3) x3,y3 ]
# [ (2,1) x4,y4 ]  [ (2,2) x5,y5 ]  [ (2,3) x6,y6 ]
# <div id="89d3ca7c-0d99-4062-8619-24d0f41e283d" style="height: 600px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("89d3ca7c-0d99-4062-8619-24d0f41e283d", [{"x": ["Pure Storage", "Violin Memory", "Nutanix"], "y": [534.856468, 268.412808, 312.2], "type": "bar", "uid": "55d0302c-ecf6-11e8-82e0-a45e60ef22d3", "xaxis": "x", "yaxis": "y"}, {"name": "Test", "x": ["Pure Storage", "Violin Memory", "Nutanix"], "y": [0.0, 0.0, 0.0], "type": "bar", "uid": "55d0c546-ecf6-11e8-85ea-a45e60ef22d3", "xaxis": "x2", "yaxis": "y2"}, {"name": "Test", "x": ["Pure Storage", "Violin Memory", "Nutanix"], "y": [10.0, 9.777777777777779, 10.0], "type": "bar", "uid": "55d13a08-ecf6-11e8-b81c-a45e60ef22d3", "xaxis": "x3", "yaxis": "y3"}], {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Total Funding", "x": 0.14444444444444446, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Rounds", "x": 0.5, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Investor Rating", "x": 0.8555555555555556, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}], "xaxis": {"anchor": "y", "domain": [0.0, 0.2888888888888889]}, "yaxis": {"anchor": "x", "domain": [0.625, 1.0]}, "xaxis2": {"anchor": "y2", "domain": [0.35555555555555557, 0.6444444444444445]}, "yaxis2": {"anchor": "x2", "domain": [0.625, 1.0]}, "xaxis3": {"anchor": "y3", "domain": [0.7111111111111111, 1.0]}, "yaxis3": {"anchor": "x3", "domain": [0.625, 1.0]}, "xaxis4": {"anchor": "y4", "domain": [0.0, 0.2888888888888889]}, "yaxis4": {"anchor": "x4", "domain": [0.0, 0.375]}, "xaxis5": {"anchor": "y5", "domain": [0.35555555555555557, 0.6444444444444445]}, "yaxis5": {"anchor": "x5", "domain": [0.0, 0.375]}, "xaxis6": {"anchor": "y6", "domain": [0.7111111111111111, 1.0]}, "yaxis6": {"anchor": "x6", "domain": [0.0, 0.375]}, "height": 600, "width": 800, "showlegend": false, "title": "Companies Similar To *Pure Storage*"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
#        company_name       company_market   company_city  \
# 1598   Pure Storage              Storage  Mountain View
# 1899  Violin Memory           Technology    Santa Clara
# 2339        Nutanix  Enterprise Software       San Jose
#
#                              company_category_list   company_city  \
# 1598                 |Storage|Enterprise Software|  Mountain View
# 1899           |Technology|Storage|Semiconductors|    Santa Clara
# 2339  |Virtualization|Storage|Enterprise Software|       San Jose
#
#       total_funding  investor_rating  company_max_round  keyword_clusters  \
# 1598     534.856468        10.000000                0.0                19
# 1899     268.412808         9.777778                0.0                19
# 2339     312.200000        10.000000                0.0                19
#
#       final_cluster
# 1598            723
# 1899            723
# 2339            723

# %%
#Code Is Deployed In Web App. See App Folder
